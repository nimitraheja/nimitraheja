# %% [markdown]
# <a href="https://colab.research.google.com/github/nimitraheja/nimitraheja/blob/main/Column_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
df=pd.read_csv('/content/covid_toy.csv')

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['has_covid']),df['has_covid'],
                                                test_size=0.2)

# %%
X_train
# Out:
#     age  gender  fever   cough       city
# 21   73    Male   98.0    Mild  Bangalore
# 70   68  Female  101.0  Strong      Delhi
# 87   47    Male  101.0  Strong  Bangalore
# 41   82    Male    NaN    Mild    Kolkata
# 86   25    Male  104.0    Mild  Bangalore
# ..  ...     ...    ...     ...        ...
# 93   27    Male  100.0    Mild    Kolkata
# 48   66    Male   99.0  Strong  Bangalore
# 13   64    Male  102.0    Mild  Bangalore
# 18   64  Female   98.0    Mild  Bangalore
# 27   33  Female  102.0  Strong      Delhi
#
# [80 rows x 5 columns]

# %% [markdown]
# 1.aama jindagi

# %%
si = SimpleImputer()
X_train_fever = si.fit_transform(X_train[['fever']])

# also the test data
X_test_fever = si.fit_transform(X_test[['fever']])
X_test_fever.shape
# Out:
# (20, 1)

# %%
oe=OrdinalEncoder(categories=[['Mild','Strong']])
X_train_cough=oe.fit_transform(X_train[['cough']])
X_test_cough=oe.fit_transform(X_test[['cough']])
X_test_cough.shape
# Out:
# (20, 1)

# %%
# OneHotEncoding -> gender,city
ohe = OneHotEncoder(drop='first',sparse_output=False)
X_train_gender_city = ohe.fit_transform(X_train[['gender','city']])

# also the test data
X_test_gender_city = ohe.transform(X_test[['gender','city']])

X_train_gender_city.shape
# Out:
# (80, 4)

# %%
# Extracting Age
X_train_age = X_train.drop(columns=['gender','fever','cough','city']).values

# also the test data
X_test_age = X_test.drop(columns=['gender','fever','cough','city']).values

X_train_age.shape
# Out:
# (80, 1)

# %%
X_train_transformed=np.concatenate((X_train_age,X_train_fever,X_train_gender_city,X_train_cough),axis=1)
X_test_transformed=np.concatenate((X_test_age,X_test_fever,X_test_gender_city,X_test_cough),axis=1)
X_train_transformed
# Out:
# array([[ 73.        ,  98.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,   0.        ],
#        [ 68.        , 101.        ,   0.        ,   1.        ,
#           0.        ,   0.        ,   1.        ],
#        [ 47.        , 101.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,   1.        ],
#        [ 82.        , 100.80821918,   1.        ,   0.        ,
#           1.        ,   0.        ,   0.        ],
#        [ 25.        , 104.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,   0.        ],
#        [ 65.        ,  99.        ,   1.        ,   1.        ,
#           0.        ,   0.        ,   0.        ],
#        [ 49.        , 102.        ,   0.        ,   1.        ,
#           0.        ,   0.        ,   0.        ],
#        [ 19.        , 100.        ,   0.        ,   0.        ,
#           1.        ,   0.        ,   0.        ],
# ...

# %% [markdown]
# 2.mentos zindagi/column transform

# %%
from sklearn.compose import ColumnTransformer

# %%
transformer = ColumnTransformer(transformers=[
    ('tnf1',SimpleImputer(),['fever']),
    ('tnf2',OrdinalEncoder(categories=[['Mild','Strong']]),['cough']),
    ('tnf3',OneHotEncoder(sparse_output=False,drop='first'),['gender','city'])
],remainder='passthrough')

# %%
transformer.fit_transform(X_train)
# Out:
# array([[ 98.        ,   0.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,  73.        ],
#        [101.        ,   1.        ,   0.        ,   1.        ,
#           0.        ,   0.        ,  68.        ],
#        [101.        ,   1.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,  47.        ],
#        [100.80821918,   0.        ,   1.        ,   0.        ,
#           1.        ,   0.        ,  82.        ],
#        [104.        ,   0.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,  25.        ],
#        [ 99.        ,   0.        ,   1.        ,   1.        ,
#           0.        ,   0.        ,  65.        ],
#        [102.        ,   0.        ,   0.        ,   1.        ,
#           0.        ,   0.        ,  49.        ],
#        [100.        ,   0.        ,   0.        ,   0.        ,
#           1.        ,   0.        ,  19.        ],
# ...
